# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials('d219dc70ac034b68862b8f5389dfef5c', '7ac6dce2bbe34b03b0b58afb58ec66cf'))

# %%
#https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE
tracks = spotify.playlist_tracks('5ABHKGoOzxkaa28ttQV9sE')
type(tracks)
# Out:
# dict

# %%
tracks.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
type(tracks['items'])
# Out:
# list

# %%
type(tracks['items'][0])
# Out:
# dict

# %%
tracks['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
track = tracks['items'][8]

# %%
track['track'].keys()
# Out:
# dict_keys(['preview_url', 'available_markets', 'explicit', 'type', 'episode', 'track', 'album', 'artists', 'disc_number', 'track_number', 'duration_ms', 'external_ids', 'external_urls', 'href', 'id', 'name', 'popularity', 'uri', 'is_local'])

# %%
track['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tIP7SsRs7vjIcLrU85W8J'},
#   'href': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J',
#   'id': '2tIP7SsRs7vjIcLrU85W8J',
#   'name': 'The Kid LAROI',
#   'type': 'artist',
#   'uri': 'spotify:artist:2tIP7SsRs7vjIcLrU85W8J'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#   'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#   'id': '1uNFoZAHBGtllmzznpCI3s',
#   'name': 'Justin Bieber',
#   'type': 'artist',
#   'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}]

# %%
names = []
ids = []
duration = []
for track in tracks['items']:
    ids.append(track['track']['id'])
    names.append(track['track']['name'])
    duration.append(track['track']['duration_ms']/1000)

# %%
import pandas as pd
df = pd.DataFrame({'id': ids, 'name': names, 'duration': duration})
df
# Out:
#                         id                                 name  duration
# 0   0VjIjW4GlUZAMYd2vXMi3b                      Blinding Lights   200.040
# 1   7qiZfU4dY1lWllzX7mPBI3                         Shape of You   233.712
# 2   7qEHsqek33rTcFNT9PFqLf                    Someone You Loved   182.160
# 3   4Dvkj6JhhA12EX05fT7y2e                            As It Was   167.303
# 4   5aAx2yezTd8zXrkmtKl66Z                              Starboy   230.453
# ..                     ...                                  ...       ...
# 95  2ekn2ttSfGqwhhate0LSR0                            New Rules   209.320
# 96  19IXtXdLSZnsCKbvjEhUOl                   Brilliant Disguise   226.046
# 97  463CkQjx2Zk1yXoBuierM9            Levitating (feat. DaBaby)   203.064
# 98  5QO79kh1waicV47BqGRL3g                      Save Your Tears   215.626
# 99  5T8EDUDqKcs6OSOwEsfqG7  Don't Stop Me Now - Remastered 2011   209.413
#
# [100 rows x 3 columns]

# %%
from IPython.display import display, HTML

def display_scrollable_dataframe(df, max_height=400):
    html = df.to_html(classes="scroll-table")
    style = f"""
    <style>
    .scroll-table {{
        height: {max_height}px;
        overflow: auto;
        display: block;
    }}
    .scroll-table thead {{
        position: sticky;
        top: 0;
        background-color: white;
    }}
    </style>
    """
    display(HTML(style + html))

display_scrollable_dataframe(df)

import pandas as pd
pd.set_option('display.max_rows', None)  # Show all rows


names = []
ids = []
duration = []
artists_list = []

# Extract data from the track dictionary
for track in tracks['items']:
    ids.append(track['track']['id'])
    names.append(track['track']['name'])
    duration.append(track['track']['duration_ms'] / 1000)
    
    # Get artist names
    artists = [artist['name'] for artist in track['track']['artists']]
    artists_list.append(artists)

# Find the max number of artists in any track
max_artists = max(len(artists) for artists in artists_list)

# Create columns dynamically
columns = ['id', 'name', 'duration'] + [f'artist_{i+1}' for i in range(max_artists)]

# Fill DataFrame
data = []
for i in range(len(ids)):
    row = [ids[i], names[i], duration[i]] + artists_list[i] + [''] * (max_artists - len(artists_list[i]))
    data.append(row)

df = pd.DataFrame(data, columns=columns)
df
# Out:
#     <style>
#     .scroll-table {
#         height: 400px;
#         overflow: auto;
#         display: block;
#     }
#     .scroll-table thead {
#         position: sticky;
#         top: 0;
#         background-color: white;
#     }
#     </style>
#     <table border="1" class="dataframe scroll-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>duration</th>
#       <th>artist_1</th>
#       <th>artist_2</th>
#       <th>artist_3</th>
#       <th>artist_4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0VjIjW4GlUZAMYd2vXMi3b</td>
#       <td>Blinding Lights</td>
#       <td>200.040</td>
#       <td>The Weeknd</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7qiZfU4dY1lWllzX7mPBI3</td>
#       <td>Shape of You</td>
#       <td>233.712</td>
#       <td>Ed Sheeran</td>
#       <td></td>
#       <td></td>
# ...
